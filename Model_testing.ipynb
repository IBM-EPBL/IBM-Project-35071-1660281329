# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
model = load_model("Gesture.h5") #loading the model for testing
path = r'C:\Users\mrith\Desktop\dataset\sam.jpg'

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
imgs = mpimg.imread(path)
imgplot = plt.imshow(imgs)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#loading of the image
img = image.load_img(path,
                     color_mode='grayscale',
                     target_size= (64,64))
x = image.img_to_array(img)#image to array
x.shape
# Out:
# (64, 64, 1)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
#changing the shape
x = np.expand_dims(x,axis = 0)

# %%
x.shape
# Out:
# (1, 64, 64, 1)

# %%
pred = model.predict_classes(x)#predicting the classes
pred
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-d1717e243d63> in <module>
# ----> 1 pred = model.predict_classes(x)#predicting the classes
#       2 pred
#
# AttributeError: 'Sequential' object has no attribute 'predict_classes'

# %%
index=['0','1','2','3','4','5']
result=str(index[pred[0]])
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-184e543b8a29> in <module>
#       1 index=['0','1','2','3','4','5']
# ----> 2 result=str(index[pred[0]])
#       3 result
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
import numpy as np
p = []

for i in range(0,6):
    for j in range(0,5):
        path = r'C:\Users\mrith\Desktop\dataset\test\'+str(i)+"\\"+str(j)+".jpg"
        img = image.load_img(path,color_mode = "grayscale",target_size= (64,64))
        x = image.img_to_array(img)
        x = np.expand_dims(x,axis = 0)
        pred = np.argmax(model.predict(x), axis=-1)
        p.append(pred)
print(p)
# Out:
#   File "<ipython-input-30-749f239ae0fb>", line 6
#     path = r'C:\Users\mrith\Desktop\dataset\test\'+str(i)+"\\"+str(j)+".jpg"
#                                                                             ^
# SyntaxError: EOL while scanning string literal

# %%
result = []
index=['0','1','2','3','4','5']
for i in p:
    result.append(index[i[0]])
    
print(result)
# Out:
# []
